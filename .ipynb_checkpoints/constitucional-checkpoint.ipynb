# %%
import string
import re
import nltk
from nltk.corpus import stopwords
import networkx as nx
import matplotlib.pyplot as plt
import operator

# %% [markdown]
# ## read data

# %%
f = open("constitucion.txt", "r") 
constitucion=f.read()

# %%
constitucion
# Out:
# 'Capítulo I\n\n     BASES DE LA INSTITUCIONALIDAD\n\n\n\n\n     Artículo 1°.- Las personas nacen libres e iguales en dignidad y derechos.\n     La familia es el núcleo fundamental de la sociedad.\n     El Estado reconoce y ampara a los grupos intermedios a través de los cuales se organiza y estructura la sociedad y les garantiza la adecuada autonomía para cumplir sus propios fines específicos.\n     El Estado está al servicio de la persona humana y su finalidad es promover el bien común, para lo cual debe contribuir a crear las condiciones sociales que permitan a todos y a cada uno de los integrantes de la comunidad nacional su mayor realización espiritual y material posible, con pleno respeto a los derechos y garantías que esta Constitución establece.\n     Es deber del Estado resguardar la seguridad nacional, dar protección a la población y a la familia, propender al fortalecimiento de ésta, promover la integración armónica de todos los sectores de la Nación y asegurar el derecho de las personas a participar con igualdad de oportunidades en la vida nacional.\n\n\n\n     Artículo 2º.- Son emblemas nacionales la bandera nacional, el escudo de armas de la República y el himno nacional.\n\n\n\n\n     Artículo 3º.- El Estado de Chile es unitario.\n     La administración del Estado será funcional y territorialmente descentralizada, o desconcentrada en su caso, de conformidad a la ley.\n     Los órganos del Estado promoverán el fortalecimiento de la regionalización del país y el desarrollo equitativo y solidario entre las regiones, provincias y comunas del territorio nacional.\n\n\n\n     Artículo 4°.- Chile es una república democrática.\n\n\n\n\n     Artículo 5º.- La soberanía reside esencialmente en la Nación. Su ejercicio se realiza por el pueblo a través del plebiscito y de elecciones periódicas y, también, por las autoridades que esta Constitución establece. Ningún sector del pueblo ni individuo alguno puede atribuirse su ejercicio.\n     El ejercicio de la soberanía reconoce como limitación el respeto a los derechos esenciales que emanan de la naturaleza humana. Es deber de los órganos del Estado respetar y promover tales derechos, garantizados por esta Constitución, así como por los tratados internacionales ratificados por Chile y que se encuentren vigentes.\n\n\n\n     Artículo 6º.- Los órganos del Estado deben someter su acción a la Constitución y a las normas dictadas conforme a ella, y garantizar el orden institucional de la República.\n     Los preceptos de esta Constitución obligan tanto a los titulares o integrantes de dichos órganos como a toda persona, institución o grupo.\n     La infracción de esta norma generará las responsabilidades y sanciones que determine la ley.\n\n\n\n     Artículo 7º.- Los órganos del Estado actúan válidamente previa investidura regular de sus integrantes, dentro de su competencia y en la forma que prescriba la ley.\n     Ninguna magistratura, ninguna persona ni grupo de personas pueden atribuirse, ni aun a pretexto de circunstancias extraordinarias, otra autoridad o derechos que los que expresamente se les hayan conferido en virtud de la Constitución o las leyes.\n     Todo acto en contravención a este artículo es nulo y originará las responsabilidades y sanciones que la ley señale.\n\n\n\n\n     Artículo 8º.- El ejercicio de las funciones públicas obliga a sus titulares a dar estricto cumplimiento al principio de probidad en todas sus actuaciones.\n     Son públicos los actos y resoluciones de los órganos del Estado, así como sus fundamentos y los procedimientos que utilicen. Sin embargo, sólo una ley de quórum calificado podrá establecer la reserva o secreto de aquéllos o de éstos, cuando la publicidad afectare el debido cumplimiento de las funciones de dichos órganos, los derechos de las personas, la seguridad de la Nación o el interés nacional.\n     El Presidente de la República, los Ministros de Estado, los diputados y senadores, y las demás autoridades y funcionarios que una ley or ...

# %%
def clean(text):
    text=text.split('\n') #line marker
    text=[s.strip() for s in text if len(s)>0] #blank strings and remove blank characters
    text=[s.lower() for s in text] #lower strings
    table = str.maketrans({key: None for key in string.punctuation}) #remove punctuation
    text=[s.translate(table) for s in text]
    text=[s.split(' ') for s in text] #word-tokenization
    text=[[w for w in s if w not in ['artículo','capítulo']] for s in text] #remove two meaningless words
    pattern = re.compile('\W')
    text=[[re.sub(pattern, '', w) for w in s] for s in text] #remove non-alphanumeric characters from strings
    text=[[w for w in s if not w.isdigit()] for s in text] #remove digits
    text=[[w for w in s if w not in set(stopwords.words('spanish'))] for s in text] #remove stopwords
    text=[s for s in text if len(s)>1] #remove shorter sentences

    return text

# %%
clean(constitucion)
# Out:
# [['bases', 'institucionalidad'],
#  ['personas', 'nacen', 'libres', 'iguales', 'dignidad', 'derechos'],
#  ['familia', 'núcleo', 'fundamental', 'sociedad'],
#  ['reconoce',
#   'ampara',
#   'grupos',
#   'intermedios',
#   'través',
#   'cuales',
#   'organiza',
#   'estructura',
#   'sociedad',
#   'garantiza',
#   'adecuada',
#   'autonomía',
#   'cumplir',
#   'propios',
#   'fines',
#   'específicos'],
#  ['servicio',
#   'persona',
#   'humana',
#   'finalidad',
#   'promover',
#   'bien',
#   'común',
#   'debe',
#   'contribuir',
#   'crear',
#   'condiciones',
#   'sociales',
#   'permitan',
#   'cada',
#   'integrantes',
#   'comunidad',
#   'nacional',
#   'mayor',
#   'realización',
#   'espiritual',
#   'material',
#   'posible',
#   'pleno',
#   'respeto',
#   'derechos',
#   'garantías',
#   'constitución',
#   'establece'],
#  ['deber',
#   'resguardar',
#   'seguridad',
#   'nacional',
#   'dar',
#   'protección',
#   'población',
#   'familia',
#   'propender',
#   'fortalecimiento',
#   'ésta',
#   'promover',
#   'integración',
#   'armónica',
#   'sectores',
#   'nación',
#   'asegurar',
#   'derecho',
#   'personas',
#   'participar',
#   'igualdad',
#   'oportunidades',
#   'vida',
#   'nacional'],
#  ['2º',
#   'emblemas',
#   'nacionales',
#   'bandera',
#   'nacional',
#   'escudo',
#   'armas',
#   'república',
#   'himno',
#   'nacional'],
#  ['3º', 'chile', 'unitario'],
#  ['administración',
#   'funcional',
#   'territorialmente',
#   'descentralizada',
#   'desconcentrada',
#   'caso',
#   'conformidad',
#   'ley'],
#  ['órganos',
#   'promoverán',
#   'fortalecimiento',
#   'regionalización',
#   'país',
#   'desarrollo',
#   'equitativo',
#   'solidario',
#   'regiones',
#   'provincias',
#   'comunas',
#   'territorio',
#   'nacional'],
#  ['chile', 'república', 'democrática'],
#  ['5º',
#   'soberanía',
#   'reside',
#   'esencialmente',
#   'nación',
#   'ejercicio',
#   'realiza',
#   'pueblo',
#   'través',
#   'plebiscito',
#   'elecciones',
#   'periódicas',
#   'autoridades',
#   'constitución',
#   'establece',
#   'ningún',
#   'sector',
#   'pueblo',
#   'individuo',
#   'alguno',
#   'puede',
#   'atribuirse',
#   'ejercicio'],
#  ['ejercicio',
#   'soberanía',
#   'reconoce',
#   'limitación',
#   'respeto',
#   'derechos',
#   'esenciales',
#   'emanan',
#   'naturaleza',
#   'humana',
#   'deber',
#   'órganos',
#   'respetar',
#   'promover',
#   'tales',
#   'derechos',
#   'garantizados',
#   'constitución',
#   'así',
#   'tratados',
#   'internacionales',
#   'ratificados',
#   'chile',
#   'encuentren',
#   'vigentes'],
#  ['6º',
#   'órganos',
#   'deben',
#   'someter',
#   'acción',
#   'constitución',
#   'normas',
#   'dictadas',
#   'conforme',
#   'garantizar',
#   'orden',
#   'institucional',
#   'república'],
#  ['preceptos',
#   'constitución',
#   'obligan',
#   'titulares',
#   'integrantes',
#   'dichos',
#   'órganos',
#   'toda',
#   'persona',
#   'institución',
#   'grupo'],
#  ['infracción',
#   'norma',
#   'generará',
#   'responsabilidades',
#   'sanciones',
#   'determine',
#   'ley'],
#  ['7º',
#   'órganos',
#   'actúan',
#   'válidamente',
#   'previa',
#   'investidura',
#   'regular',
#   'integrantes',
#   'dentro',
#   'competencia',
#   'forma',
#   'prescriba',
#   'ley'],
#  ['ninguna',
#   'magistratura',
#   'ninguna',
#   'persona',
#   'grupo',
#   'personas',
#   'pueden',
#   'atribuirse',
#   'aun',
#   'pretexto',
#   'circunstancias',
#   'extraordinarias',
#   'autoridad',
#   'derechos',
#   'expresamente',
#   'conferido',
#   'virtud',
#   'constitución',
#   'leyes'],
#  ['acto',
#   'contravención',
#   'nulo',
#   'originará',
#   'responsabilidades',
#   'sanciones',
#   'ley',
#   'señale'],
#  ['8º',
#   'ejercicio',
#   'funciones',
#   'públicas',
#   'obliga',
#   'titulares',
#   'dar',
#   'estricto',
#   'cumplimiento',
#   'principio',
#   'probidad',
#   'todas',
#   'actuaciones'],
#  ['públicos',
#   'actos',
#   'resoluciones',
#   'órganos',
#   'así',
#   'fundamentos',
#   'procedimientos',
#   'utilicen',
#   'embargo',
#   'sólo',
#   'ley',
#   'quórum',
#   'calificado',
#   'podrá',
#   'establecer',
#   'reserva',
#   'secreto',
#   'aquéllos',
#   'éstos',
#   'publicidad',
#   'afectare',
#   'debido',
#   'cumplimiento',
#   'funciones',
#   'dichos',
#   'órganos',
#   'derechos',
#   'personas',
#   'seguridad',
#   'nación',
#   'interés',
#   'nacional'],
#  ['presidente',
#   'república',
#   'ministros',
#   'diputados',
#   'senadores',
#   'demás',
#   'autoridades',
#   'funcionarios',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'señale',
#   'deberán',
#   'declarar',
#   'intereses',
#   'patrimonio',
#   'forma',
#   'pública'],
#  ['dicha',
#   'ley',
#   'determinará',
#   'casos',
#   'condiciones',
#   'autoridades',
#   'delegarán',
#   'terceros',
#   'administración',
#   'aquellos',
#   'bienes',
#   'obligaciones',
#   'supongan',
#   'conflicto',
#   'interés',
#   'ejercicio',
#   'función',
#   'pública',
#   'asimismo',
#   'podrá',
#   'considerar',
#   'medidas',
#   'apropiadas',
#   'resolverlos',
#   'situaciones',
#   'calificadas',
#   'disponer',
#   'enajenación',
#   'parte',
#   'bienes'],
#  ['9º',
#   'terrorismo',
#   'cualquiera',
#   'formas',
#   'esencia',
#   'contrario',
#   'derechos',
#   'humanos'],
#  ['ley',
#   'quórum',
#   'calificado',
#   'determinará',
#   'conductas',
#   'terroristas',
#   'penalidad',
#   'responsables',
#   'delitos',
#   'quedarán',
#   'inhabilitados',
#   'plazo',
#   'quince',
#   'años',
#   'ejercer',
#   'funciones',
#   'cargos',
#   'públicos',
#   'elección',
#   'popular',
#   'rector',
#   'director',
#   'establecimiento',
#   'educación',
#   'ejercer',
#   'funciones',
#   'enseñanza',
#   'explotar',
#   'medio',
#   'comunicación',
#   'social',
#   'ser',
#   'director',
#   'administrador',
#   'mismo',
#   'desempeñar',
#   'funciones',
#   'relacionadas',
#   'emisión',
#   'difusión',
#   'opiniones',
#   'informaciones',
#   'podrá',
#   'ser',
#   'dirigentes',
#   'organizaciones',
#   'políticas',
#   'relacionadas',
#   'educación',
#   'carácter',
#   'vecinal',
#   'profesional',
#   'empresarial',
#   'sindical',
#   'estudiantil',
#   'gremial',
#   'general',
#   'dicho',
#   'plazo',
#   'anterior',
#   'entiende',
#   'perjuicio',
#   'inhabilidades',
#   'mayor',
#   'tiempo',
#   'establezca',
#   'ley'],
#  ['delitos',
#   'refiere',
#   'inciso',
#   'anterior',
#   'considerados',
#   'siempre',
#   'comunes',
#   'políticos',
#   'efectos',
#   'legales',
#   'procederá',
#   'respecto',
#   'indulto',
#   'particular',
#   'salvo',
#   'conmutar',
#   'pena',
#   'muerte',
#   'presidio',
#   'perpetuo'],
#  ['nacionalidad', 'ciudadania'],
#  ['1º',
#   'nacidos',
#   'territorio',
#   'chile',
#   'excepción',
#   'hijos',
#   'extranjeros',
#   'encuentren',
#   'chile',
#   'servicio',
#   'gobierno',
#   'hijos',
#   'extranjeros',
#   'transeúntes',
#   'embargo',
#   'podrán',
#   'optar',
#   'nacionalidad',
#   'chilena'],
#  ['2º',
#   'hijos',
#   'padre',
#   'madre',
#   'chilenos',
#   'nacidos',
#   'territorio',
#   'extranjero',
#   'requerirá',
#   'alguno',
#   'ascendientes',
#   'línea',
#   'recta',
#   'primer',
#   'segundo',
#   'grado',
#   'adquirido',
#   'nacionalidad',
#   'chilena',
#   'virtud',
#   'establecido',
#   'números',
#   '1º',
#   '3º',
#   'ó',
#   '4º'],
#  ['3º',
#   'extranjeros',
#   'obtuvieren',
#   'carta',
#   'nacionalización',
#   'conformidad',
#   'ley'],
#  ['4º', 'obtuvieren', 'especial', 'gracia', 'nacionalización', 'ley'],
#  ['ley',
#   'reglamentará',
#   'procedimientos',
#   'opción',
#   'nacionalidad',
#   'chilena',
#   'otorgamiento',
#   'negativa',
#   'cancelación',
#   'cartas',
#   'nacionalización',
#   'formación',
#   'registro',
#   'actos'],
#  ['nacionalidad', 'chilena', 'pierde'],
#  ['1º',
#   'renuncia',
#   'voluntaria',
#   'manifestada',
#   'autoridad',
#   'chilena',
#   'competente',
#   'renuncia',
#   'sólo',
#   'producirá',
#   'efectos',
#   'si',
#   'persona',
#   'previamente',
#   'nacionalizado',
#   'país',
#   'extranjero'],
#  ['2º',
#   'decreto',
#   'supremo',
#   'caso',
#   'prestación',
#   'servicios',
#   'guerra',
#   'exterior',
#   'enemigos',
#   'chile',
#   'aliados'],
#  ['3º', 'cancelación', 'carta', 'nacionalización'],
#  ['4º', 'ley', 'revoque', 'nacionalización', 'concedida', 'gracia'],
#  ['hubieren',
#   'perdido',
#   'nacionalidad',
#   'chilena',
#   'cualquiera',
#   'causales',
#   'establecidas',
#   'sólo',
#   'podrán',
#   'ser',
#   'rehabilitados',
#   'ley'],
#  ['persona',
#   'afectada',
#   'acto',
#   'resolución',
#   'autoridad',
#   'administrativa',
#   'prive',
#   'nacionalidad',
#   'chilena',
#   'desconozca',
#   'podrá',
#   'recurrir',
#   'cualquiera',
#   'nombre',
#   'dentro',
#   'plazo',
#   'treinta',
#   'días',
#   'corte',
#   'suprema',
#   'conocerá',
#   'jurado',
#   'tribunal',
#   'pleno',
#   'interposición',
#   'recurso',
#   'suspenderá',
#   'efectos',
#   'acto',
#   'resolución',
#   'recurridos'],
#  ['ciudadanos',
#   'chilenos',
#   'cumplido',
#   'dieciocho',
#   'años',
#   'edad',
#   'sido',
#   'condenados',
#   'pena',
#   'aflictiva'],
#  ['calidad',
#   'ciudadano',
#   'otorga',
#   'derechos',
#   'sufragio',
#   'optar',
#   'cargos',
#   'elección',
#   'popular',
#   'demás',
#   'constitución',
#   'ley',
#   'confieran'],
#  ['ciudadanos',
#   'derecho',
#   'sufragio',
#   'encuentren',
#   'país',
#   'podrán',
#   'sufragar',
#   'extranjero',
#   'elecciones',
#   'primarias',
#   'presidenciales',
#   'elecciones',
#   'presidente',
#   'república',
#   'plebiscitos',
#   'nacionales',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'establecerá',
#   'procedimiento',
#   'materializar',
#   'inscripción',
#   'registro',
#   'electoral',
#   'regulará',
#   'manera',
#   'realizarán',
#   'procesos',
#   'electorales',
#   'plebiscitarios',
#   'extranjero',
#   'conformidad',
#   'dispuesto',
#   'incisos',
#   'primero',
#   'segundo'],
#  ['tratándose',
#   'chilenos',
#   'refieren',
#   'números',
#   '2º',
#   '4º',
#   'ejercicio',
#   'derechos',
#   'confiere',
#   'ciudadanía',
#   'sujeto',
#   'hubieren',
#   'avecindados',
#   'chile',
#   'año'],
#  ['extranjeros',
#   'avecindados',
#   'chile',
#   'cinco',
#   'años',
#   'cumplan',
#   'requisitos',
#   'señalados',
#   'inciso',
#   'primero',
#   'podrán',
#   'ejercer',
#   'derecho',
#   'sufragio',
#   'casos',
#   'formas',
#   'determine',
#   'ley'],
#  ['nacionalizados',
#   'conformidad',
#   'nº',
#   '3º',
#   'opción',
#   'cargos',
#   'públicos',
#   'elección',
#   'popular',
#   'sólo',
#   'después',
#   'cinco',
#   'años',
#   'posesión',
#   'cartas',
#   'nacionalización'],
#  ['votaciones',
#   'populares',
#   'sufragio',
#   'personal',
#   'igualitario',
#   'secreto',
#   'voluntario'],
#  ['sólo',
#   'podrá',
#   'convocarse',
#   'votación',
#   'popular',
#   'elecciones',
#   'plebiscitos',
#   'expresamente',
#   'previstos',
#   'constitución'],
#  ['derecho', 'sufragio', 'suspende'],
#  ['1º', 'interdicción', 'caso', 'demencia'],
#  ['2º',
#   'hallarse',
#   'persona',
#   'acusada',
#   'delito',
#   'merezca',
#   'pena',
#   'aflictiva',
#   'delito',
#   'ley',
#   'califique',
#   'conducta',
#   'terrorista'],
#  ['3º',
#   'haber',
#   'sido',
#   'sancionado',
#   'tribunal',
#   'constitucional',
#   'conformidad',
#   'inciso',
#   'séptimo',
#   'número',
#   '15º',
#   'constitución',
#   'causa',
#   'hallaren',
#   'privados',
#   'ejercicio',
#   'derecho',
#   'sufragio',
#   'recuperarán',
#   'término',
#   'cinco',
#   'años',
#   'contado',
#   'declaración',
#   'tribunal',
#   'suspensión',
#   'producirá',
#   'efecto',
#   'legal',
#   'perjuicio',
#   'dispuesto',
#   'inciso',
#   'séptimo',
#   'número',
#   '15º'],
#  ['calidad', 'ciudadano', 'pierde'],
#  ['1º', 'pérdida', 'nacionalidad', 'chilena'],
#  ['2º', 'condena', 'pena', 'aflictiva'],
#  ['3º',
#   'condena',
#   'delitos',
#   'ley',
#   'califique',
#   'conducta',
#   'terrorista',
#   'relativos',
#   'tráfico',
#   'estupefacientes',
#   'hubieren',
#   'merecido',
#   'además',
#   'pena',
#   'aflictiva'],
#  ['hubieren',
#   'perdido',
#   'ciudadanía',
#   'causal',
#   'indicada',
#   'número',
#   '2º',
#   'recuperarán',
#   'conformidad',
#   'ley',
#   'vez',
#   'extinguida',
#   'responsabilidad',
#   'penal',
#   'hubieren',
#   'perdido',
#   'causales',
#   'previstas',
#   'número',
#   '3º',
#   'podrán',
#   'solicitar',
#   'rehabilitación',
#   'senado',
#   'vez',
#   'cumplida',
#   'condena'],
#  ['sistema',
#   'electoral',
#   'público',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'determinará',
#   'organización',
#   'funcionamiento',
#   'regulará',
#   'forma',
#   'realizarán',
#   'procesos',
#   'electorales',
#   'plebiscitarios',
#   'previsto',
#   'constitución',
#   'garantizará',
#   'siempre',
#   'plena',
#   'igualdad',
#   'independientes',
#   'miembros',
#   'partidos',
#   'políticos',
#   'presentación',
#   'candidaturas',
#   'participación',
#   'señalados',
#   'procesos',
#   'dicha',
#   'ley',
#   'establecerá',
#   'sistema',
#   'financiamiento',
#   'transparencia',
#   'límite',
#   'control',
#   'gasto',
#   'electoral'],
#  ['ley',
#   'orgánica',
#   'constitucional',
#   'contemplará',
#   'además',
#   'sistema',
#   'registro',
#   'electoral',
#   'bajo',
#   'dirección',
#   'servicio',
#   'electoral',
#   'incorporarán',
#   'solo',
#   'ministerio',
#   'ley',
#   'cumplan',
#   'requisitos',
#   'establecidos',
#   'constitución'],
#  ['resguardo',
#   'orden',
#   'público',
#   'actos',
#   'electorales',
#   'plebiscitarios',
#   'corresponderá',
#   'fuerzas',
#   'armadas',
#   'carabineros',
#   'modo',
#   'indique',
#   'ley'],
#  ['derechos', 'deberes', 'constitucionales'],
#  ['constitución', 'asegura', 'todas', 'personas'],
#  ['1º', 'derecho', 'vida', 'integridad', 'física', 'psíquica', 'persona'],
#  ['ley', 'protege', 'vida', 'nacer'],
#  ['pena',
#   'muerte',
#   'sólo',
#   'podrá',
#   'establecerse',
#   'delito',
#   'contemplado',
#   'ley',
#   'aprobada',
#   'quórum',
#   'calificado'],
#  ['prohíbe', 'aplicación', 'apremio', 'ilegítimo'],
#  ['2º',
#   'igualdad',
#   'ley',
#   'chile',
#   'persona',
#   'grupo',
#   'privilegiados',
#   'chile',
#   'esclavos',
#   'pise',
#   'territorio',
#   'queda',
#   'libre',
#   'hombres',
#   'mujeres',
#   'iguales',
#   'ley'],
#  ['ley',
#   'autoridad',
#   'alguna',
#   'podrán',
#   'establecer',
#   'diferencias',
#   'arbitrarias'],
#  ['3º', 'igual', 'protección', 'ley', 'ejercicio', 'derechos'],
#  ['toda',
#   'persona',
#   'derecho',
#   'defensa',
#   'jurídica',
#   'forma',
#   'ley',
#   'señale',
#   'ninguna',
#   'autoridad',
#   'individuo',
#   'podrá',
#   'impedir',
#   'restringir',
#   'perturbar',
#   'debida',
#   'intervención',
#   'letrado',
#   'si',
#   'hubiere',
#   'sido',
#   'requerida',
#   'tratándose',
#   'integrantes',
#   'fuerzas',
#   'armadas',
#   'orden',
#   'seguridad',
#   'pública',
#   'derecho',
#   'regirá',
#   'concerniente',
#   'administrativo',
#   'disciplinario',
#   'normas',
#   'pertinentes',
#   'respectivos',
#   'estatutos'],
#  ['ley',
#   'arbitrará',
#   'medios',
#   'otorgar',
#   'asesoramiento',
#   'defensa',
#   'jurídica',
#   'puedan',
#   'procurárselos',
#   'mismos',
#   'ley',
#   'señalará',
#   'casos',
#   'establecerá',
#   'forma',
#   'personas',
#   'naturales',
#   'víctimas',
#   'delitos',
#   'dispondrán',
#   'asesoría',
#   'defensa',
#   'jurídica',
#   'gratuitas',
#   'efecto',
#   'ejercer',
#   'acción',
#   'penal',
#   'reconocida',
#   'constitución',
#   'leyes'],
#  ['toda',
#   'persona',
#   'imputada',
#   'delito',
#   'derecho',
#   'irrenunciable',
#   'ser',
#   'asistida',
#   'abogado',
#   'defensor',
#   'proporcionado',
#   'si',
#   'nombrare',
#   'oportunidad',
#   'establecida',
#   'ley'],
#  ['nadie',
#   'podrá',
#   'ser',
#   'juzgado',
#   'comisiones',
#   'especiales',
#   'sino',
#   'tribunal',
#   'señalare',
#   'ley',
#   'hallare',
#   'establecido',
#   'ésta',
#   'anterioridad',
#   'perpetración',
#   'hecho'],
#  ['toda',
#   'sentencia',
#   'órgano',
#   'ejerza',
#   'jurisdicción',
#   'debe',
#   'fundarse',
#   'proceso',
#   'previo',
#   'legalmente',
#   'tramitado',
#   'corresponderá',
#   'legislador',
#   'establecer',
#   'siempre',
#   'garantías',
#   'procedimiento',
#   'investigación',
#   'racionales',
#   'justos'],
#  ['ley', 'podrá', 'presumir', 'derecho', 'responsabilidad', 'penal'],
#  ['ningún',
#   'delito',
#   'castigará',
#   'pena',
#   'señale',
#   'ley',
#   'promulgada',
#   'anterioridad',
#   'perpetración',
#   'menos',
#   'nueva',
#   'ley',
#   'favorezca',
#   'afectado'],
#  ['ninguna',
#   'ley',
#   'podrá',
#   'establecer',
#   'penas',
#   'conducta',
#   'sanciona',
#   'expresamente',
#   'descrita'],
#  ['4º',
#   'respeto',
#   'protección',
#   'vida',
#   'privada',
#   'honra',
#   'persona',
#   'familia',
#   'asimismo',
#   'protección',
#   'datos',
#   'personales',
#   'tratamiento',
#   'protección',
#   'datos',
#   'efectuará',
#   'forma',
#   'condiciones',
#   'determine',
#   'ley'],
#  ['5º',
#   'inviolabilidad',
#   'hogar',
#   'toda',
#   'forma',
#   'comunicación',
#   'privada',
#   'hogar',
#   'sólo',
#   'puede',
#   'allanarse',
#   'comunicaciones',
#   'documentos',
#   'privados',
#   'interceptarse',
#   'abrirse',
#   'registrarse',
#   'casos',
#   'formas',
#   'determinados',
#   'ley'],
#  ['6º',
#   'libertad',
#   'conciencia',
#   'manifestación',
#   'todas',
#   'creencias',
#   'ejercicio',
#   'libre',
#   'cultos',
#   'opongan',
#   'moral',
#   'buenas',
#   'costumbres',
#   'orden',
#   'público'],
#  ['confesiones',
#   'religiosas',
#   'podrán',
#   'erigir',
#   'conservar',
#   'templos',
#   'dependencias',
#   'bajo',
#   'condiciones',
#   'seguridad',
#   'higiene',
#   'fijadas',
#   'leyes',
#   'ordenanzas'],
#  ['iglesias',
#   'confesiones',
#   'instituciones',
#   'religiosas',
#   'cualquier',
#   'culto',
#   'derechos',
#   'otorgan',
#   'reconocen',
#   'respecto',
#   'bienes',
#   'leyes',
#   'actualmente',
#   'vigor',
#   'templos',
#   'dependencias',
#   'destinados',
#   'exclusivamente',
#   'servicio',
#   'culto',
#   'exentos',
#   'toda',
#   'clase',
#   'contribuciones'],
#  ['7º', 'derecho', 'libertad', 'personal', 'seguridad', 'individual'],
#  ['toda',
#   'persona',
#   'derecho',
#   'residir',
#   'permanecer',
#   'cualquier',
#   'lugar',
#   'república',
#   'trasladarse',
#   'entrar',
#   'salir',
#   'territorio',
#   'condición',
#   'guarden',
#   'normas',
#   'establecidas',
#   'ley',
#   'salvo',
#   'siempre',
#   'perjuicio',
#   'terceros'],
#  ['b',
#   'nadie',
#   'puede',
#   'ser',
#   'privado',
#   'libertad',
#   'personal',
#   'ésta',
#   'restringida',
#   'sino',
#   'casos',
#   'forma',
#   'determinados',
#   'constitución',
#   'leyes'],
#  ['c',
#   'nadie',
#   'puede',
#   'ser',
#   'arrestado',
#   'detenido',
#   'sino',
#   'orden',
#   'funcionario',
#   'público',
#   'expresamente',
#   'facultado',
#   'ley',
#   'después',
#   'dicha',
#   'orden',
#   'intimada',
#   'forma',
#   'legal',
#   'embargo',
#   'podrá',
#   'ser',
#   'detenido',
#   'fuere',
#   'sorprendido',
#   'delito',
#   'flagrante',
#   'solo',
#   'objeto',
#   'ser',
#   'puesto',
#   'disposición',
#   'juez',
#   'competente',
#   'dentro',
#   'veinticuatro',
#   'horas',
#   'siguientes'],
#  ['si',
#   'autoridad',
#   'hiciere',
#   'arrestar',
#   'detener',
#   'alguna',
#   'persona',
#   'deberá',
#   'dentro',
#   'cuarenta',
#   'ocho',
#   'horas',
#   'siguientes',
#   'dar',
#   'aviso',
#   'juez',
#   'competente',
#   'poniendo',
#   'disposición',
#   'afectado',
#   'juez',
#   'podrá',
#   'resolución',
#   'fundada',
#   'ampliar',
#   'plazo',
#   'cinco',
#   'días',
#   'diez',
#   'días',
#   'caso',
#   'investigaren',
#   'hechos',
#   'calificados',
#   'ley',
#   'conductas',
#   'terroristas'],
#  ['d',
#   'nadie',
#   'puede',
#   'ser',
#   'arrestado',
#   'detenido',
#   'sujeto',
#   'prisión',
#   'preventiva',
#   'preso',
#   'sino',
#   'casa',
#   'lugares',
#   'públicos',
#   'destinados',
#   'objeto'],
#  ['encargados',
#   'prisiones',
#   'pueden',
#   'recibir',
#   'nadie',
#   'calidad',
#   'arrestado',
#   'detenido',
#   'procesado',
#   'preso',
#   'dejar',
#   'constancia',
#   'orden',
#   'correspondiente',
#   'emanada',
#   'autoridad',
#   'facultad',
#   'legal',
#   'registro',
#   'público'],
#  ['ninguna',
#   'incomunicación',
#   'puede',
#   'impedir',
#   'funcionario',
#   'encargado',
#   'casa',
#   'detención',
#   'visite',
#   'arrestado',
#   'detenido',
#   'procesado',
#   'preso',
#   'encuentre',
#   'funcionario',
#   'obligado',
#   'siempre',
#   'arrestado',
#   'detenido',
#   'requiera',
#   'transmitir',
#   'juez',
#   'competente',
#   'copia',
#   'orden',
#   'detención',
#   'reclamar',
#   'dé',
#   'dicha',
#   'copia',
#   'dar',
#   'mismo',
#   'certificado',
#   'hallarse',
#   'detenido',
#   'aquel',
#   'individuo',
#   'si',
#   'tiempo',
#   'detención',
#   'hubiere',
#   'omitido',
#   'requisito'],
#  ['libertad',
#   'imputado',
#   'procederá',
#   'menos',
#   'detención',
#   'prisión',
#   'preventiva',
#   'considerada',
#   'juez',
#   'necesaria',
#   'investigaciones',
#   'seguridad',
#   'ofendido',
#   'sociedad',
#   'ley',
#   'establecerá',
#   'requisitos',
#   'modalidades',
#   'obtenerla'],
#  ['apelación',
#   'resolución',
#   'pronuncie',
#   'libertad',
#   'imputado',
#   'delitos',
#   'refiere',
#   'conocida',
#   'tribunal',
#   'superior',
#   'corresponda',
#   'integrado',
#   'exclusivamente',
#   'miembros',
#   'titulares',
#   'resolución',
#   'apruebe',
#   'u',
#   'otorgue',
#   'requerirá',
#   'ser',
#   'acordada',
#   'unanimidad',
#   'mientras',
#   'dure',
#   'libertad',
#   'imputado',
#   'quedará',
#   'siempre',
#   'sometido',
#   'medidas',
#   'vigilancia',
#   'autoridad',
#   'ley',
#   'contemple'],
#  ['f',
#   'causas',
#   'criminales',
#   'podrá',
#   'obligar',
#   'imputado',
#   'acusado',
#   'declare',
#   'bajo',
#   'juramento',
#   'hecho',
#   'propio',
#   'tampoco',
#   'podrán',
#   'ser',
#   'obligados',
#   'declarar',
#   'éste',
#   'ascendientes',
#   'descendientes',
#   'cónyuge',
#   'demás',
#   'personas',
#   'según',
#   'casos',
#   'circunstancias',
#   'señale',
#   'ley'],
#  ['g',
#   'podrá',
#   'imponerse',
#   'pena',
#   'confiscación',
#   'bienes',
#   'perjuicio',
#   'comiso',
#   'casos',
#   'establecidos',
#   'leyes',
#   'dicha',
#   'pena',
#   'procedente',
#   'respecto',
#   'asociaciones',
#   'ilícitas'],
#  ['h',
#   'podrá',
#   'aplicarse',
#   'sanción',
#   'pérdida',
#   'derechos',
#   'previsionales'],
#  ['i',
#   'vez',
#   'dictado',
#   'sobreseimiento',
#   'definitivo',
#   'sentencia',
#   'absolutoria',
#   'hubiere',
#   'sido',
#   'sometido',
#   'proceso',
#   'condenado',
#   'cualquier',
#   'instancia',
#   'resolución',
#   'corte',
#   'suprema',
#   'declare',
#   'injustificadamente',
#   'errónea',
#   'arbitraria',
#   'derecho',
#   'ser',
#   'indemnizado',
#   'perjuicios',
#   'patrimoniales',
#   'morales',
#   'sufrido',
#   'indemnización',
#   'determinada',
#   'judicialmente',
#   'procedimiento',
#   'breve',
#   'sumario',
#   'prueba',
#   'apreciará',
#   'conciencia'],
#  ['8º',
#   'derecho',
#   'vivir',
#   'medio',
#   'ambiente',
#   'libre',
#   'contaminación',
#   'deber',
#   'velar',
#   'derecho',
#   'afectado',
#   'tutelar',
#   'preservación',
#   'naturaleza'],
#  ['ley',
#   'podrá',
#   'establecer',
#   'restricciones',
#   'específicas',
#   'ejercicio',
#   'determinados',
#   'derechos',
#   'libertades',
#   'proteger',
#   'medio',
#   'ambiente'],
#  ['9º', 'derecho', 'protección', 'salud'],
#  ['protege',
#   'libre',
#   'igualitario',
#   'acceso',
#   'acciones',
#   'promoción',
#   'protección',
#   'recuperación',
#   'salud',
#   'rehabilitación',
#   'individuo'],
#  ['corresponderá',
#   'asimismo',
#   'coordinación',
#   'control',
#   'acciones',
#   'relacionadas',
#   'salud'],
#  ['deber',
#   'preferente',
#   'garantizar',
#   'ejecución',
#   'acciones',
#   'salud',
#   'presten',
#   'través',
#   'instituciones',
#   'públicas',
#   'privadas',
#   'forma',
#   'condiciones',
#   'determine',
#   'ley',
#   'podrá',
#   'establecer',
#   'cotizaciones',
#   'obligatorias'],
#  ['cada',
#   'persona',
#   'derecho',
#   'elegir',
#   'sistema',
#   'salud',
#   'desee',
#   'acogerse',
#   'éste',
#   'estatal',
#   'privado'],
#  ['10º', 'derecho', 'educación'],
#  ['educación',
#   'objeto',
#   'pleno',
#   'desarrollo',
#   'persona',
#   'distintas',
#   'etapas',
#   'vida'],
#  ['padres',
#   'derecho',
#   'preferente',
#   'deber',
#   'educar',
#   'hijos',
#   'corresponderá',
#   'otorgar',
#   'especial',
#   'protección',
#   'ejercicio',
#   'derecho'],
#  ['obligatorio',
#   'promover',
#   'educación',
#   'parvularia',
#   'financiará',
#   'sistema',
#   'gratuito',
#   'partir',
#   'nivel',
#   'medio',
#   'menor',
#   'destinado',
#   'asegurar',
#   'acceso',
#   'éste',
#   'niveles',
#   'superiores',
#   'segundo',
#   'nivel',
#   'transición',
#   'obligatorio',
#   'siendo',
#   'requisito',
#   'ingreso',
#   'educación',
#   'básica'],
#  ['educación',
#   'básica',
#   'educación',
#   'media',
#   'obligatorias',
#   'debiendo',
#   'financiar',
#   'sistema',
#   'gratuito',
#   'tal',
#   'objeto',
#   'destinado',
#   'asegurar',
#   'acceso',
#   'toda',
#   'población',
#   'caso',
#   'educación',
#   'media',
#   'sistema',
#   'conformidad',
#   'ley',
#   'extenderá',
#   'cumplir',
#   'años',
#   'edad'],
#  ['corresponderá',
#   'asimismo',
#   'fomentar',
#   'desarrollo',
#   'educación',
#   'niveles',
#   'estimular',
#   'investigación',
#   'científica',
#   'tecnológica',
#   'creación',
#   'artística',
#   'protección',
#   'incremento',
#   'patrimonio',
#   'cultural',
#   'nación'],
#  ['deber',
#   'comunidad',
#   'contribuir',
#   'desarrollo',
#   'perfeccionamiento',
#   'educación'],
#  ['11º',
#   'libertad',
#   'enseñanza',
#   'incluye',
#   'derecho',
#   'abrir',
#   'organizar',
#   'mantener',
#   'establecimientos',
#   'educacionales'],
#  ['libertad',
#   'enseñanza',
#   'limitaciones',
#   'impuestas',
#   'moral',
#   'buenas',
#   'costumbres',
#   'orden',
#   'público',
#   'seguridad',
#   'nacional'],
#  ['enseñanza',
#   'reconocida',
#   'oficialmente',
#   'podrá',
#   'orientarse',
#   'propagar',
#   'tendencia',
#   'político',
#   'partidista',
#   'alguna'],
#  ['padres', 'derecho', 'escoger', 'establecimiento', 'enseñanza', 'hijos'],
#  ['ley',
#   'orgánica',
#   'constitucional',
#   'establecerá',
#   'requisitos',
#   'mínimos',
#   'deberán',
#   'exigirse',
#   'cada',
#   'niveles',
#   'enseñanza',
#   'básica',
#   'media',
#   'señalará',
#   'normas',
#   'objetivas',
#   'general',
#   'aplicación',
#   'permitan',
#   'velar',
#   'cumplimiento',
#   'dicha',
#   'ley',
#   'mismo',
#   'modo',
#   'establecerá',
#   'requisitos',
#   'reconocimiento',
#   'oficial',
#   'establecimientos',
#   'educacionales',
#   'nivel'],
#  ['12º',
#   'libertad',
#   'emitir',
#   'opinión',
#   'informar',
#   'censura',
#   'previa',
#   'cualquier',
#   'forma',
#   'cualquier',
#   'medio',
#   'perjuicio',
#   'responder',
#   'delitos',
#   'abusos',
#   'cometan',
#   'ejercicio',
#   'libertades',
#   'conformidad',
#   'ley',
#   'deberá',
#   'ser',
#   'quórum',
#   'calificado'],
#  ['ley',
#   'ningún',
#   'caso',
#   'podrá',
#   'establecer',
#   'monopolio',
#   'estatal',
#   'medios',
#   'comunicación',
#   'social'],
#  ['toda',
#   'persona',
#   'natural',
#   'jurídica',
#   'ofendida',
#   'injustamente',
#   'aludida',
#   'algún',
#   'medio',
#   'comunicación',
#   'social',
#   'derecho',
#   'declaración',
#   'rectificación',
#   'gratuitamente',
#   'difundida',
#   'condiciones',
#   'ley',
#   'determine',
#   'medio',
#   'comunicación',
#   'social',
#   'información',
#   'sido',
#   'emitida'],
#  ['toda',
#   'persona',
#   'natural',
#   'jurídica',
#   'derecho',
#   'fundar',
#   'editar',
#   'mantener',
#   'diarios',
#   'revistas',
#   'periódicos',
#   'condiciones',
#   'señale',
#   'ley'],
#  ['aquellas',
#   'universidades',
#   'demás',
#   'personas',
#   'entidades',
#   'ley',
#   'determine',
#   'podrán',
#   'establecer',
#   'operar',
#   'mantener',
#   'estaciones',
#   'televisión'],
#  ['consejo',
#   'nacional',
#   'televisión',
#   'autónomo',
#   'personalidad',
#   'jurídica',
#   'encargado',
#   'velar',
#   'correcto',
#   'funcionamiento',
#   'medio',
#   'comunicación',
#   'ley',
#   'quórum',
#   'calificado',
#   'señalará',
#   'organización',
#   'demás',
#   'funciones',
#   'atribuciones',
#   'referido',
#   'consejo'],
#  ['ley',
#   'regulará',
#   'sistema',
#   'calificación',
#   'exhibición',
#   'producción',
#   'cinematográfica'],
#  ['13º', 'derecho', 'reunirse', 'pacíficamente', 'permiso', 'previo', 'armas'],
#  ['reuniones',
#   'plazas',
#   'calles',
#   'demás',
#   'lugares',
#   'uso',
#   'público',
#   'regirán',
#   'disposiciones',
#   'generales',
#   'policía'],
#  ['14º',
#   'derecho',
#   'presentar',
#   'peticiones',
#   'autoridad',
#   'cualquier',
#   'asunto',
#   'interés',
#   'público',
#   'privado',
#   'limitación',
#   'proceder',
#   'términos',
#   'respetuosos',
#   'convenientes'],
#  ['15º', 'derecho', 'asociarse', 'permiso', 'previo'],
#  ['gozar',
#   'personalidad',
#   'jurídica',
#   'asociaciones',
#   'deberán',
#   'constituirse',
#   'conformidad',
#   'ley'],
#  ['nadie', 'puede', 'ser', 'obligado', 'pertenecer', 'asociación'],
#  ['prohíbense',
#   'asociaciones',
#   'contrarias',
#   'moral',
#   'orden',
#   'público',
#   'seguridad'],
#  ['partidos',
#   'políticos',
#   'podrán',
#   'intervenir',
#   'actividades',
#   'ajenas',
#   'propias',
#   'tener',
#   'privilegio',
#   'alguno',
#   'monopolio',
#   'participación',
#   'ciudadana',
#   'nómina',
#   'militantes',
#   'registrará',
#   'servicio',
#   'electoral',
#   'guardará',
#   'reserva',
#   'misma',
#   'accesible',
#   'militantes',
#   'respectivo',
#   'partido',
#   'contabilidad',
#   'deberá',
#   'ser',
#   'pública',
#   'fuentes',
#   'financiamiento',
#   'podrán',
#   'provenir',
#   'dineros',
#   'bienes',
#   'donaciones',
#   'aportes',
#   'créditos',
#   'origen',
#   'extranjero',
#   'estatutos',
#   'deberán',
#   'contemplar',
#   'normas',
#   'aseguren',
#   'efectiva',
#   'democracia',
#   'interna',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'establecerá',
#   'sistema',
#   'elecciones',
#   'primarias',
#   'podrá',
#   'ser',
#   'utilizado',
#   'dichos',
#   'partidos',
#   'nominación',
#   'candidatos',
#   'cargos',
#   'elección',
#   'popular',
#   'cuyos',
#   'resultados',
#   'vinculantes',
#   'colectividades',
#   'salvo',
#   'excepciones',
#   'establezca',
#   'dicha',
#   'ley',
#   'aquellos',
#   'resulten',
#   'elegidos',
#   'elecciones',
#   'primarias',
#   'podrán',
#   'ser',
#   'candidatos',
#   'elección',
#   'respectivo',
#   'cargo',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'regulará',
#   'demás',
#   'materias',
#   'conciernan',
#   'sanciones',
#   'aplicarán',
#   'incumplimiento',
#   'preceptos',
#   'dentro',
#   'cuales',
#   'podrá',
#   'considerar',
#   'disolución',
#   'asociaciones',
#   'movimientos',
#   'organizaciones',
#   'grupos',
#   'personas',
#   'persigan',
#   'realicen',
#   'actividades',
#   'propias',
#   'partidos',
#   'políticos',
#   'ajustarse',
#   'normas',
#   'anteriores',
#   'ilícitos',
#   'sancionados',
#   'acuerdo',
#   'referida',
#   'ley',
#   'orgánica',
#   'constitucional'],
#  ['constitución',
#   'política',
#   'garantiza',
#   'pluralismo',
#   'político',
#   'inconstitucionales',
#   'partidos',
#   'movimientos',
#   'u',
#   'formas',
#   'organización',
#   'cuyos',
#   'objetivos',
#   'actos',
#   'conductas',
#   'respeten',
#   'principios',
#   'básicos',
#   'régimen',
#   'democrático',
#   'constitucional',
#   'procuren',
#   'establecimiento',
#   'sistema',
#   'totalitario',
#   'asimismo',
#   'aquellos',
#   'hagan',
#   'uso',
#   'violencia',
#   'propugnen',
#   'inciten',
#   'método',
#   'acción',
#   'política',
#   'corresponderá',
#   'tribunal',
#   'constitucional',
#   'declarar',
#   'inconstitucionalidad'],
#  ['perjuicio',
#   'demás',
#   'sanciones',
#   'establecidas',
#   'constitución',
#   'ley',
#   'personas',
#   'hubieren',
#   'participación',
#   'hechos',
#   'motiven',
#   'declaración',
#   'inconstitucionalidad',
#   'refiere',
#   'inciso',
#   'precedente',
#   'podrán',
#   'participar',
#   'formación',
#   'partidos',
#   'políticos',
#   'movimientos',
#   'u',
#   'formas',
#   'organización',
#   'política',
#   'optar',
#   'cargos',
#   'públicos',
#   'elección',
#   'popular',
#   'desempeñar',
#   'cargos',
#   'mencionan',
#   'números',
#   'término',
#   'cinco',
#   'años',
#   'contado',
#   'resolución',
#   'tribunal',
#   'si',
#   'fecha',
#   'personas',
#   'referidas',
#   'estuvieren',
#   'posesión',
#   'funciones',
#   'cargos',
#   'indicados',
#   'perderán',
#   'pleno',
#   'derecho'],
#  ['personas',
#   'sancionadas',
#   'virtud',
#   'precepto',
#   'podrán',
#   'ser',
#   'objeto',
#   'rehabilitación',
#   'plazo',
#   'señalado',
#   'inciso',
#   'anterior',
#   'duración',
#   'inhabilidades',
#   'contempladas',
#   'dicho',
#   'inciso',
#   'elevará',
#   'doble',
#   'caso',
#   'reincidencia'],
#  ['16º', 'libertad', 'trabajo', 'protección'],
#  ['toda',
#   'persona',
#   'derecho',
#   'libre',
#   'contratación',
#   'libre',
#   'elección',
#   'trabajo',
#   'justa',
#   'retribución'],
#  ['prohíbe',
#   'cualquiera',
#   'discriminación',
#   'base',
#   'capacidad',
#   'idoneidad',
#   'personal',
#   'perjuicio',
#   'ley',
#   'pueda',
#   'exigir',
#   'nacionalidad',
#   'chilena',
#   'límites',
#   'edad',
#   'determinados',
#   'casos'],
#  ['ninguna',
#   'clase',
#   'trabajo',
#   'puede',
#   'ser',
#   'prohibida',
#   'salvo',
#   'oponga',
#   'moral',
#   'seguridad',
#   'salubridad',
#   'públicas',
#   'exija',
#   'interés',
#   'nacional',
#   'ley',
#   'declare',
#   'así',
#   'ninguna',
#   'ley',
#   'disposición',
#   'autoridad',
#   'pública',
#   'podrá',
#   'exigir',
#   'afiliación',
#   'organización',
#   'entidad',
#   'alguna',
#   'requisito',
#   'desarrollar',
#   'determinada',
#   'actividad',
#   'trabajo',
#   'desafiliación',
#   'mantenerse',
#   'éstos',
#   'ley',
#   'determinará',
#   'profesiones',
#   'requieren',
#   'grado',
#   'título',
#   'universitario',
#   'condiciones',
#   'deben',
#   'cumplirse',
#   'ejercerlas',
#   'colegios',
#   'profesionales',
#   'constituidos',
#   'conformidad',
#   'ley',
#   'digan',
#   'relación',
#   'tales',
#   'profesiones',
#   'facultados',
#   'conocer',
#   'reclamaciones',
#   'interpongan',
#   'conducta',
#   'ética',
#   'miembros',
#   'resoluciones',
#   'podrá',
#   'apelarse',
#   'corte',
#   'apelaciones',
#   'respectiva',
#   'profesionales',
#   'asociados',
#   'juzgados',
#   'tribunales',
#   'especiales',
#   'establecidos',
#   'ley'],
#  ['negociación',
#   'colectiva',
#   'empresa',
#   'laboren',
#   'derecho',
#   'trabajadores',
#   'salvo',
#   'casos',
#   'ley',
#   'expresamente',
#   'permita',
#   'negociar',
#   'ley',
#   'establecerá',
#   'modalidades',
#   'negociación',
#   'colectiva',
#   'procedimientos',
#   'adecuados',
#   'lograr',
#   'solución',
#   'justa',
#   'pacífica',
#   'ley',
#   'señalará',
#   'casos',
#   'negociación',
#   'colectiva',
#   'deba',
#   'someterse',
#   'arbitraje',
#   'obligatorio',
#   'corresponderá',
#   'tribunales',
#   'especiales',
#   'expertos',
#   'cuya',
#   'organización',
#   'atribuciones',
#   'establecerán'],
#  ['podrán',
#   'declararse',
#   'huelga',
#   'funcionarios',
#   'municipalidades',
#   'tampoco',
#   'podrán',
#   'hacerlo',
#   'personas',
#   'trabajen',
#   'corporaciones',
#   'empresas',
#   'cualquiera',
#   'naturaleza',
#   'finalidad',
#   'función',
#   'atiendan',
#   'servicios',
#   'utilidad',
#   'pública',
#   'cuya',
#   'paralización',
#   'cause',
#   'grave',
#   'daño',
#   'salud',
#   'economía',
#   'país',
#   'abastecimiento',
#   'población',
#   'seguridad',
#   'nacional',
#   'ley',
#   'establecerá',
#   'procedimientos',
#   'determinar',
#   'corporaciones',
#   'empresas',
#   'cuyos',
#   'trabajadores',
#   'sometidos',
#   'prohibición',
#   'establece',
#   'inciso'],
#  ['17º',
#   'admisión',
#   'todas',
#   'funciones',
#   'empleos',
#   'públicos',
#   'requisitos',
#   'impongan',
#   'constitución',
#   'leyes'],
#  ['18º', 'derecho', 'seguridad', 'social'],
#  ['leyes', 'regulen', 'ejercicio', 'derecho', 'quórum', 'calificado'],
#  ['acción',
#   'dirigida',
#   'garantizar',
#   'acceso',
#   'habitantes',
#   'goce',
#   'prestaciones',
#   'básicas',
#   'uniformes',
#   'otorguen',
#   'través',
#   'instituciones',
#   'públicas',
#   'privadas',
#   'ley',
#   'podrá',
#   'establecer',
#   'cotizaciones',
#   'obligatorias'],
#  ['supervigilará', 'adecuado', 'ejercicio', 'derecho', 'seguridad', 'social'],
#  ['19º',
#   'derecho',
#   'sindicarse',
#   'casos',
#   'forma',
#   'señale',
#   'ley',
#   'afiliación',
#   'sindical',
#   'siempre',
#   'voluntaria'],
#  ['organizaciones',
#   'sindicales',
#   'gozarán',
#   'personalidad',
#   'jurídica',
#   'solo',
#   'hecho',
#   'registrar',
#   'estatutos',
#   'actas',
#   'constitutivas',
#   'forma',
#   'condiciones',
#   'determine',
#   'ley'],
#  ['ley',
#   'contemplará',
#   'mecanismos',
#   'aseguren',
#   'autonomía',
#   'organizaciones',
#   'organizaciones',
#   'sindicales',
#   'podrán',
#   'intervenir',
#   'actividades',
#   'político',
#   'partidistas'],
#  ['20º',
#   'igual',
#   'repartición',
#   'tributos',
#   'proporción',
#   'rentas',
#   'progresión',
#   'forma',
#   'fije',
#   'ley',
#   'igual',
#   'repartición',
#   'demás',
#   'cargas',
#   'públicas'],
#  ['ningún',
#   'caso',
#   'ley',
#   'podrá',
#   'establecer',
#   'tributos',
#   'manifiestamente',
#   'desproporcionados',
#   'injustos'],
#  ['tributos',
#   'recauden',
#   'cualquiera',
#   'naturaleza',
#   'ingresarán',
#   'patrimonio',
#   'nación',
#   'podrán',
#   'afectos',
#   'destino',
#   'determinado'],
#  ['embargo',
#   'ley',
#   'podrá',
#   'autorizar',
#   'determinados',
#   'tributos',
#   'puedan',
#   'afectados',
#   'fines',
#   'propios',
#   'defensa',
#   'nacional',
#   'asimismo',
#   'podrá',
#   'autorizar',
#   'gravan',
#   'actividades',
#   'bienes',
#   'clara',
#   'identificación',
#   'regional',
#   'local',
#   'puedan',
#   'ser',
#   'aplicados',
#   'dentro',
#   'marcos',
#   'misma',
#   'ley',
#   'señale',
#   'autoridades',
#   'regionales',
#   'comunales',
#   'financiamiento',
#   'obras',
#   'desarrollo'],
#  ['21º',
#   'derecho',
#   'desarrollar',
#   'cualquiera',
#   'actividad',
#   'económica',
#   'contraria',
#   'moral',
#   'orden',
#   'público',
#   'seguridad',
#   'nacional',
#   'respetando',
#   'normas',
#   'legales',
#   'regulen'],
#  ['organismos',
#   'podrán',
#   'desarrollar',
#   'actividades',
#   'empresariales',
#   'participar',
#   'sólo',
#   'si',
#   'ley',
#   'quórum',
#   'calificado',
#   'autoriza',
#   'tal',
#   'caso',
#   'actividades',
#   'sometidas',
#   'legislación',
#   'común',
#   'aplicable',
#   'particulares',
#   'perjuicio',
#   'excepciones',
#   'motivos',
#   'justificados',
#   'establezca',
#   'ley',
#   'deberá',
#   'ser',
#   'asimismo',
#   'quórum',
#   'calificado'],
#  ['22º',
#   'discriminación',
#   'arbitraria',
#   'trato',
#   'deben',
#   'dar',
#   'organismos',
#   'materia',
#   'económica'],
#  ['sólo',
#   'virtud',
#   'ley',
#   'siempre',
#   'signifique',
#   'tal',
#   'discriminación',
#   'podrán',
#   'autorizar',
#   'determinados',
#   'beneficios',
#   'directos',
#   'indirectos',
#   'favor',
#   'algún',
#   'sector',
#   'actividad',
#   'zona',
#   'geográfica',
#   'establecer',
#   'gravámenes',
#   'especiales',
#   'afecten',
#   'u',
#   'caso',
#   'franquicias',
#   'beneficios',
#   'indirectos',
#   'estimación',
#   'costo',
#   'éstos',
#   'deberá',
#   'incluirse',
#   'anualmente',
#   'ley',
#   'presupuestos'],
#  ['23º',
#   'libertad',
#   'adquirir',
#   'dominio',
#   'toda',
#   'clase',
#   'bienes',
#   'excepto',
#   'aquellos',
#   'naturaleza',
#   'hecho',
#   'comunes',
#   'hombres',
#   'deban',
#   'pertenecer',
#   'nación',
#   'toda',
#   'ley',
#   'declare',
#   'así',
#   'anterior',
#   'perjuicio',
#   'prescrito',
#   'preceptos',
#   'constitución'],
#  ['ley',
#   'quórum',
#   'calificado',
#   'así',
#   'exija',
#   'interés',
#   'nacional',
#   'puede',
#   'establecer',
#   'limitaciones',
#   'requisitos',
#   'adquisición',
#   'dominio',
#   'bienes'],
#  ['24º',
#   'derecho',
#   'propiedad',
#   'diversas',
#   'especies',
#   'toda',
#   'clase',
#   'bienes',
#   'corporales',
#   'incorporales'],
#  ['sólo',
#   'ley',
#   'puede',
#   'establecer',
#   'modo',
#   'adquirir',
#   'propiedad',
#   'usar',
#   'gozar',
#   'disponer',
#   'limitaciones',
#   'obligaciones',
#   'deriven',
#   'función',
#   'social',
#   'comprende',
#   'cuanto',
#   'exijan',
#   'intereses',
#   'generales',
#   'nación',
#   'seguridad',
#   'nacional',
#   'utilidad',
#   'salubridad',
#   'públicas',
#   'conservación',
#   'patrimonio',
#   'ambiental'],
#  ['nadie',
#   'puede',
#   'caso',
#   'alguno',
#   'ser',
#   'privado',
#   'propiedad',
#   'bien',
#   'recae',
#   'alguno',
#   'atributos',
#   'facultades',
#   'esenciales',
#   'dominio',
#   'sino',
#   'virtud',
#   'ley',
#   'general',
#   'especial',
#   'autorice',
#   'expropiación',
#   'causa',
#   'utilidad',
#   'pública',
#   'interés',
#   'nacional',
#   'calificada',
#   'legislador',
#   'expropiado',
#   'podrá',
#   'reclamar',
#   'legalidad',
#   'acto',
#   'expropiatorio',
#   'tribunales',
#   'ordinarios',
#   'siempre',
#   'derecho',
#   'indemnización',
#   'daño',
#   'patrimonial',
#   'efectivamente',
#   'causado',
#   'fijará',
#   'común',
#   'acuerdo',
#   'sentencia',
#   'dictada',
#   'conforme',
#   'derecho',
#   'dichos',
#   'tribunales'],
#  ['falta',
#   'acuerdo',
#   'indemnización',
#   'deberá',
#   'ser',
#   'pagada',
#   'dinero',
#   'efectivo',
#   'contado'],
#  ['toma',
#   'posesión',
#   'material',
#   'bien',
#   'expropiado',
#   'lugar',
#   'previo',
#   'pago',
#   'total',
#   'indemnización',
#   'falta',
#   'acuerdo',
#   'determinada',
#   'provisionalmente',
#   'peritos',
#   'forma',
#   'señale',
#   'ley',
#   'caso',
#   'reclamo',
#   'acerca',
#   'procedencia',
#   'expropiación',
#   'juez',
#   'podrá',
#   'mérito',
#   'antecedentes',
#   'invoquen',
#   'decretar',
#   'suspensión',
#   'toma',
#   'posesión'],
#  ['dominio',
#   'absoluto',
#   'exclusivo',
#   'inalienable',
#   'imprescriptible',
#   'todas',
#   'minas',
#   'comprendiéndose',
#   'éstas',
#   'covaderas',
#   'arenas',
#   'metalíferas',
#   'salares',
#   'depósitos',
#   'carbón',
#   'hidrocarburos',
#   'demás',
#   'sustancias',
#   'fósiles',
#   'excepción',
#   'arcillas',
#   'superficiales',
#   'obstante',
#   'propiedad',
#   'personas',
#   'naturales',
#   'jurídicas',
#   'terrenos',
#   'cuyas',
#   'entrañas',
#   'estuvieren',
#   'situadas',
#   'predios',
#   'superficiales',
#   'sujetos',
#   'obligaciones',
#   'limitaciones',
#   'ley',
#   'señale',
#   'facilitar',
#   'exploración',
#   'explotación',
#   'beneficio',
#   'dichas',
#   'minas'],
#  ['corresponde',
#   'ley',
#   'determinar',
#   'sustancias',
#   'aquellas',
#   'refiere',
#   'inciso',
#   'precedente',
#   'exceptuados',
#   'hidrocarburos',
#   'líquidos',
#   'gaseosos',
#   'pueden',
#   'ser',
#   'objeto',
#   'concesiones',
#   'exploración',
#   'explotación',
#   'dichas',
#   'concesiones',
#   'constituirán',
#   'siempre',
#   'resolución',
#   'judicial',
#   'duración',
#   'conferirán',
#   'derechos',
#   'impondrán',
#   'obligaciones',
#   'ley',
#   'exprese',
#   'carácter',
#   'orgánica',
#   'constitucional',
#   'concesión',
#   'minera',
#   'obliga',
#   'dueño',
#   'desarrollar',
#   'actividad',
#   'necesaria',
#   'satisfacer',
#   'interés',
#   'público',
#   'justifica',
#   'otorgamiento',
#   'régimen',
#   'amparo',
#   'establecido',
#   'dicha',
#   'ley',
#   'tenderá',
#   'directa',
#   'indirectamente',
#   'obtener',
#   'cumplimiento',
#   'obligación',
#   'contemplará',
#   'causales',
#   'caducidad',
#   'caso',
#   'incumplimiento',
#   'simple',
#   'extinción',
#   'dominio',
#   'concesión',
#   'caso',
#   'dichas',
#   'causales',
#   'efectos',
#   'deben',
#   'establecidos',
#   'momento',
#   'otorgarse',
#   'concesión'],
#  ['competencia',
#   'exclusiva',
#   'tribunales',
#   'ordinarios',
#   'justicia',
#   'declarar',
#   'extinción',
#   'tales',
#   'concesiones',
#   'controversias',
#   'produzcan',
#   'respecto',
#   'caducidad',
#   'extinción',
#   'dominio',
#   'concesión',
#   'resueltas',
#   'caso',
#   'caducidad',
#   'afectado',
#   'podrá',
#   'requerir',
#   'justicia',
#   'declaración',
#   'subsistencia',
#   'derecho'],
#  ['dominio',
#   'titular',
#   'concesión',
#   'minera',
#   'protegido',
#   'garantía',
#   'constitucional',
#   'trata',
#   'número'],
#  ['exploración',
#   'explotación',
#   'beneficio',
#   'yacimientos',
#   'contengan',
#   'sustancias',
#   'susceptibles',
#   'concesión',
#   'podrán',
#   'ejecutarse',
#   'directamente',
#   'empresas',
#   'medio',
#   'concesiones',
#   'administrativas',
#   'contratos',
#   'especiales',
#   'operación',
#   'requisitos',
#   'bajo',
#   'condiciones',
#   'presidente',
#   'república',
#   'fije',
#   'cada',
#   'caso',
#   'decreto',
#   'supremo',
#   'norma',
#   'aplicará',
#   'yacimientos',
#   'cualquier',
#   'especie',
#   'existentes',
#   'aguas',
#   'marítimas',
#   'sometidas',
#   'jurisdicción',
#   'nacional',
#   'situados',
#   'parte',
#   'zonas',
#   'conforme',
#   'ley',
#   'determinen',
#   'importancia',
#   'seguridad',
#   'nacional',
#   'presidente',
#   'república',
#   'podrá',
#   'poner',
#   'término',
#   'cualquier',
#   'tiempo',
#   'expresión',
#   'causa',
#   'indemnización',
#   'corresponda',
#   'concesiones',
#   'administrativas',
#   'contratos',
#   'operación',
#   'relativos',
#   'explotaciones',
#   'ubicadas',
#   'zonas',
#   'declaradas',
#   'importancia',
#   'seguridad',
#   'nacional'],
#  ['derechos',
#   'particulares',
#   'aguas',
#   'reconocidos',
#   'constituidos',
#   'conformidad',
#   'ley',
#   'otorgarán',
#   'titulares',
#   'propiedad'],
#  ['25º',
#   'libertad',
#   'crear',
#   'difundir',
#   'artes',
#   'así',
#   'derecho',
#   'autor',
#   'creaciones',
#   'intelectuales',
#   'artísticas',
#   'cualquier',
#   'especie',
#   'tiempo',
#   'señale',
#   'ley',
#   'inferior',
#   'vida',
#   'titular'],
#  ['derecho',
#   'autor',
#   'comprende',
#   'propiedad',
#   'obras',
#   'derechos',
#   'paternidad',
#   'edición',
#   'integridad',
#   'obra',
#   'ello',
#   'conformidad',
#   'ley'],
#  ['garantiza',
#   'propiedad',
#   'industrial',
#   'patentes',
#   'invención',
#   'marcas',
#   'comerciales',
#   'modelos',
#   'procesos',
#   'tecnológicos',
#   'u',
#   'creaciones',
#   'análogas',
#   'tiempo',
#   'establezca',
#   'ley'],
#  ['aplicable',
#   'propiedad',
#   'creaciones',
#   'intelectuales',
#   'artísticas',
#   'propiedad',
#   'industrial',
#   'prescrito',
#   'incisos',
#   'segundo',
#   'tercero',
#   'cuarto',
#   'quinto',
#   'número',
#   'anterior'],
#  ['26º',
#   'seguridad',
#   'preceptos',
#   'legales',
#   'mandato',
#   'constitución',
#   'regulen',
#   'complementen',
#   'garantías',
#   'ésta',
#   'establece',
#   'limiten',
#   'casos',
#   'autoriza',
#   'podrán',
#   'afectar',
#   'derechos',
#   'esencia',
#   'imponer',
#   'condiciones',
#   'tributos',
#   'requisitos',
#   'impidan',
#   'libre',
#   'ejercicio'],
#  ['causa',
#   'actos',
#   'u',
#   'omisiones',
#   'arbitrarios',
#   'ilegales',
#   'sufra',
#   'privación',
#   'perturbación',
#   'amenaza',
#   'legítimo',
#   'ejercicio',
#   'derechos',
#   'garantías',
#   'establecidos',
#   'números',
#   '1º',
#   '2º',
#   '3º',
#   'inciso',
#   'quinto',
#   '4º',
#   '5º',
#   '6º',
#   '9º',
#   'inciso',
#   'final',
#   '11º12º',
#   '13º',
#   '15º',
#   '16º',
#   'relativo',
#   'libertad',
#   'trabajo',
#   'derecho',
#   'libre',
#   'elección',
#   'libre',
#   'contratación',
#   'establecido',
#   'inciso',
#   'cuarto',
#   '19º',
#   '21º',
#   '22º',
#   '23º',
#   '25º',
#   'podrá',
#   'ocurrir',
#   'cualquiera',
#   'nombre',
#   'corte',
#   'apelaciones',
#   'respectiva',
#   'adoptará',
#   'inmediato',
#   'providencias',
#   'juzgue',
#   'necesarias',
#   'restablecer',
#   'imperio',
#   'derecho',
#   'asegurar',
#   'debida',
#   'protección',
#   'afectado',
#   'perjuicio',
#   'demás',
#   'derechos',
#   'pueda',
#   'hacer',
#   'valer',
#   'autoridad',
#   'tribunales',
#   'correspondientes'],
#  ['procederá',
#   'recurso',
#   'protección',
#   'caso',
#   'nº8º',
#   'derecho',
#   'vivir',
#   'medio',
#   'ambiente',
#   'libre',
#   'contaminación',
#   'afectado',
#   'acto',
#   'u',
#   'omisión',
#   'ilegal',
#   'imputable',
#   'autoridad',
#   'persona',
#   'determinada'],
#  ['individuo',
#   'hallare',
#   'arrestado',
#   'detenido',
#   'preso',
#   'infracción',
#   'dispuesto',
#   'constitución',
#   'leyes',
#   'podrá',
#   'ocurrir',
#   'cualquiera',
#   'nombre',
#   'magistratura',
#   'señale',
#   'ley',
#   'fin',
#   'ésta',
#   'ordene',
#   'guarden',
#   'formalidades',
#   'legales',
#   'adopte',
#   'inmediato',
#   'providencias',
#   'juzgue',
#   'necesarias',
#   'restablecer',
#   'imperio',
#   'derecho',
#   'asegurar',
#   'debida',
#   'protección',
#   'afectado'],
#  ['magistratura',
#   'podrá',
#   'ordenar',
#   'individuo',
#   'traído',
#   'presencia',
#   'decreto',
#   'precisamente',
#   'obedecido',
#   'encargados',
#   'cárceles',
#   'lugares',
#   'detención',
#   'instruida',
#   'antecedentes',
#   'decretará',
#   'libertad',
#   'inmediata',
#   'hará',
#   'reparen',
#   'defectos',
#   'legales',
#   'pondrá',
#   'individuo',
#   'disposición',
#   'juez',
#   'competente',
#   'procediendo',
#   'breve',
#   'sumariamente',
#   'corrigiendo',
#   'defectos',
#   'dando',
#   'cuenta',
#   'corresponda',
#   'corrija'],
#  ['mismo',
#   'recurso',
#   'igual',
#   'forma',
#   'podrá',
#   'ser',
#   'deducido',
#   'favor',
#   'toda',
#   'persona',
#   'ilegalmente',
#   'sufra',
#   'cualquiera',
#   'privación',
#   'perturbación',
#   'amenaza',
#   'derecho',
#   'libertad',
#   'personal',
#   'seguridad',
#   'individual',
#   'respectiva',
#   'magistratura',
#   'dictará',
#   'tal',
#   'caso',
#   'medidas',
#   'indicadas',
#   'incisos',
#   'anteriores',
#   'estime',
#   'conducentes',
#   'restablecer',
#   'imperio',
#   'derecho',
#   'asegurar',
#   'debida',
#   'protección',
#   'afectado'],
#  ['habitante',
#   'república',
#   'debe',
#   'respeto',
#   'chile',
#   'emblemas',
#   'nacionales'],
#  ['chilenos',
#   'deber',
#   'fundamental',
#   'honrar',
#   'patria',
#   'defender',
#   'soberanía',
#   'contribuir',
#   'preservar',
#   'seguridad',
#   'nacional',
#   'valores',
#   'esenciales',
#   'tradición',
#   'chilena'],
#  ['servicio',
#   'militar',
#   'demás',
#   'cargas',
#   'personales',
#   'imponga',
#   'ley',
#   'obligatorios',
#   'términos',
#   'formas',
#   'ésta',
#   'determine'],
#  ['chilenos',
#   'cargar',
#   'armas',
#   'deberán',
#   'hallarse',
#   'inscritos',
#   'registros',
#   'militares',
#   'si',
#   'legalmente',
#   'exceptuados'],
#  ['grupos',
#   'intermedios',
#   'comunidad',
#   'dirigentes',
#   'hagan',
#   'mal',
#   'uso',
#   'autonomía',
#   'constitución',
#   'reconoce',
#   'interviniendo',
#   'indebidamente',
#   'actividades',
#   'ajenas',
#   'fines',
#   'específicos',
#   'sancionados',
#   'conformidad',
#   'ley',
#   'incompatibles',
#   'cargos',
#   'directivos',
#   'superiores',
#   'organizaciones',
#   'gremiales',
#   'cargos',
#   'directivos',
#   'superiores',
#   'nacionales',
#   'regionales',
#   'partidos',
#   'políticos'],
#  ['ley',
#   'establecerá',
#   'sanciones',
#   'corresponda',
#   'aplicar',
#   'dirigentes',
#   'gremiales',
#   'intervengan',
#   'actividades',
#   'político',
#   'partidistas',
#   'dirigentes',
#   'partidos',
#   'políticos',
#   'interfieran',
#   'funcionamiento',
#   'organizaciones',
#   'gremiales',
#   'demás',
#   'grupos',
#   'intermedios',
#   'propia',
#   'ley',
#   'señale'],
#  ['presidente', 'república'],
#  ['gobierno',
#   'administración',
#   'corresponden',
#   'presidente',
#   'república',
#   'jefe'],
#  ['autoridad',
#   'extiende',
#   'cuanto',
#   'objeto',
#   'conservación',
#   'orden',
#   'público',
#   'interior',
#   'seguridad',
#   'externa',
#   'república',
#   'acuerdo',
#   'constitución',
#   'leyes'],
#  ['junio',
#   'cada',
#   'año',
#   'presidente',
#   'república',
#   'dará',
#   'cuenta',
#   'país',
#   'administrativo',
#   'político',
#   'nación',
#   'congreso',
#   'pleno'],
#  ['ser',
#   'elegido',
#   'presidente',
#   'república',
#   'requiere',
#   'tener',
#   'nacionalidad',
#   'chilena',
#   'acuerdo',
#   'dispuesto',
#   'números',
#   '1º',
#   'ó',
#   '2º',
#   'tener',
#   'cumplidos',
#   'treinta',
#   'cinco',
# ...
#   'mientras',
#   'dicten',
#   'correspondientes',
#   'cuerpos',
#   'legales'],
#  ['quinta',
#   'obstante',
#   'dispuesto',
#   'número',
#   '6º',
#   'mantendrán',
#   'vigencia',
#   'preceptos',
#   'legales',
#   'fecha',
#   'promulgación',
#   'constitución',
#   'hubieren',
#   'reglado',
#   'materias',
#   'comprendidas',
#   'mientras',
#   'expresamente',
#   'derogadas',
#   'ley'],
#  ['sexta',
#   'perjuicio',
#   'dispuesto',
#   'inciso',
#   'tercero',
#   'número',
#   '20º',
#   'mantendrán',
#   'vigencia',
#   'disposiciones',
#   'legales',
#   'establecido',
#   'tributos',
#   'afectación',
#   'destino',
#   'determinado',
#   'mientras',
#   'expresamente',
#   'derogadas'],
#  ['septima',
#   'indulto',
#   'particular',
#   'siempre',
#   'procedente',
#   'respecto',
#   'delitos',
#   'refiere',
#   '9º',
#   'cometidos',
#   'marzo',
#   'copia',
#   'decreto',
#   'respectivo',
#   'remitirá',
#   'carácter',
#   'reservado',
#   'senado'],
#  ['octava',
#   'normas',
#   'vii',
#   'ministerio',
#   'público',
#   'regirán',
#   'momento',
#   'entrar',
#   'vigencia',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'ministerio',
#   'público',
#   'ley',
#   'podrá',
#   'establecer',
#   'fechas',
#   'diferentes',
#   'entrada',
#   'vigor',
#   'disposiciones',
#   'determinar',
#   'aplicación',
#   'gradual',
#   'diversas',
#   'materias',
#   'regiones',
#   'país'],
#  ['vii',
#   'ministerio',
#   'público',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'ministerio',
#   'público',
#   'leyes',
#   'complementando',
#   'dichas',
#   'normas',
#   'modifiquen',
#   'código',
#   'orgánico',
#   'tribunales',
#   'código',
#   'procedimiento',
#   'penal',
#   'aplicarán',
#   'exclusivamente',
#   'hechos',
#   'acaecidos',
#   'posterioridad',
#   'entrada',
#   'vigencia',
#   'tales',
#   'disposiciones'],
#  ['novena',
#   'obstante',
#   'dispuesto',
#   'quina',
#   'cada',
#   'ternas',
#   'formen',
#   'proveer',
#   'primera',
#   'vez',
#   'cargos',
#   'fiscal',
#   'nacional',
#   'fiscales',
#   'regionales',
#   'corte',
#   'suprema',
#   'cortes',
#   'apelaciones',
#   'podrán',
#   'incluir',
#   'respectivamente',
#   'miembro',
#   'activo',
#   'poder',
#   'judicial'],
#  ['decima',
#   'atribuciones',
#   'otorgadas',
#   'municipalidades',
#   'relativas',
#   'modificación',
#   'estructura',
#   'orgánica',
#   'personal',
#   'remuneraciones',
#   'aplicables',
#   'regulen',
#   'ley',
#   'respectiva',
#   'modalidades',
#   'requisitos',
#   'limitaciones',
#   'ejercicio',
#   'nuevas',
#   'competencias'],
#  ['decimoprimera',
#   'año',
#   'siguiente',
#   'fecha',
#   'publicación',
#   'presente',
#   'ley',
#   'reforma',
#   'constitucional',
#   'podrán',
#   'figurar',
#   'nóminas',
#   'integrar',
#   'corte',
#   'suprema',
#   'desempeñado',
#   'cargos',
#   'presidente',
#   'república',
#   'diputado',
#   'senador',
#   'ministro',
#   'intendente',
#   'gobernador',
#   'alcalde'],
#  ['decimosegunda',
#   'mandato',
#   'presidente',
#   'república',
#   'ejercicio',
#   'seis',
#   'años',
#   'pudiendo',
#   'ser',
#   'reelegido',
#   'período',
#   'siguiente'],
#  ['decimotercera',
#   'senado',
#   'integrado',
#   'únicamente',
#   'senadores',
#   'electos',
#   'conformidad',
#   'constitución',
#   'política',
#   'república',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'votaciones',
#   'populares',
#   'escrutinios',
#   'actualmente',
#   'vigentes'],
#  ['modificaciones',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'votaciones',
#   'populares',
#   'escrutinios',
#   'digan',
#   'relación',
#   'número',
#   'senadores',
#   'diputados',
#   'circunscripciones',
#   'distritos',
#   'existentes',
#   'sistema',
#   'electoral',
#   'vigente',
#   'requerirán',
#   'voto',
#   'conforme',
#   'tres',
#   'quintas',
#   'partes',
#   'diputados',
#   'senadores',
#   'ejercicio'],
#  ['decimocuarta',
#   'reemplazo',
#   'actuales',
#   'ministros',
#   'nombramiento',
#   'nuevos',
#   'integrantes',
#   'tribunal',
#   'constitucional',
#   'efectuará',
#   'conforme',
#   'reglas',
#   'siguientes'],
#  ['actuales',
#   'ministros',
#   'nombrados',
#   'presidente',
#   'república',
#   'senado',
#   'corte',
#   'suprema',
#   'consejo',
#   'seguridad',
#   'nacional',
#   'mantendrán',
#   'funciones',
#   'término',
#   'período',
#   'nombrados',
#   'cesen',
#   'cargos'],
#  ['reemplazo',
#   'ministros',
#   'designados',
#   'consejo',
#   'seguridad',
#   'nacional',
#   'corresponderá',
#   'presidente',
#   'república'],
#  ['senado',
#   'nombrará',
#   'tres',
#   'ministros',
#   'tribunal',
#   'constitucional',
#   'dos',
#   'directamente',
#   'tercero',
#   'previa',
#   'propuesta',
#   'cámara',
#   'diputados',
#   'último',
#   'durará',
#   'cargo',
#   'mismo',
#   'día',
#   'cese',
#   'actualmente',
#   'nombrado',
#   'senado',
#   'quién',
#   'reemplace',
#   'conformidad',
#   'inciso',
#   'séptimo',
#   'podrá',
#   'ser',
#   'reelegido'],
#  ['actuales',
#   'ministros',
#   'corte',
#   'suprema',
#   'vez',
#   'tribunal',
#   'constitucional',
#   'quedarán',
#   'suspendidos',
#   'temporalmente',
#   'ejercicio',
#   'cargos',
#   'dicha',
#   'corte',
#   'seis',
#   'meses',
#   'después',
#   'publique',
#   'presente',
#   'reforma',
#   'constitucional',
#   'afectar',
#   'derechos',
#   'funcionarios',
#   'reasumirán',
#   'cargos',
#   'término',
#   'período',
#   'nombrados',
#   'tribunal',
#   'constitucional',
#   'cesen',
#   'último',
#   'cualquier',
#   'motivo'],
#  ['corte',
#   'suprema',
#   'nominará',
#   'conformidad',
#   'letra',
#   'c',
#   'abogados',
#   'indicados',
#   'medida',
#   'vayan',
#   'generando',
#   'vacantes',
#   'correspondientes',
#   'obstante',
#   'primero',
#   'nombrado',
#   'tres',
#   'años',
#   'segundo',
#   'seis',
#   'años',
#   'tercero',
#   'nueve',
#   'años',
#   'sido',
#   'nombrado',
#   'tres',
#   'años',
#   'podrá',
#   'ser',
#   'reelegido'],
#  ['si',
#   'alguno',
#   'actuales',
#   'ministros',
#   'contemplados',
#   'inciso',
#   'anterior',
#   'cesare',
#   'cargo',
#   'reemplazará',
#   'autoridad',
#   'indicada',
#   'letras',
#   'b',
#   'según',
#   'corresponda',
#   'período',
#   'durará',
#   'reste',
#   'antecesor',
#   'pudiendo',
#   'éstos',
#   'ser',
#   'reelegidos'],
#  ['ministros',
#   'nombrados',
#   'conformidad',
#   'disposición',
#   'deberán',
#   'ser',
#   'designados',
#   'anterioridad',
#   'diciembre',
#   'entrarán',
#   'funciones',
#   'enero'],
#  ['decimoquinta',
#   'tratados',
#   'internacionales',
#   'aprobados',
#   'congreso',
#   'nacional',
#   'anterioridad',
#   'entrada',
#   'vigor',
#   'presente',
#   'reforma',
#   'constitucional',
#   'versen',
#   'materias',
#   'conforme',
#   'constitución',
#   'deben',
#   'ser',
#   'aprobadas',
#   'mayoría',
#   'absoluta',
#   'cuatro',
#   'séptimas',
#   'partes',
#   'diputados',
#   'senadores',
#   'ejercicio',
#   'entenderá',
#   'cumplido',
#   'requisitos'],
#  ['contiendas',
#   'competencia',
#   'actualmente',
#   'trabadas',
#   'corte',
#   'suprema',
#   'entrada',
#   'vigor',
#   'modificaciones',
#   'viii',
#   'continuarán',
#   'radicadas',
#   'dicho',
#   'órgano',
#   'total',
#   'tramitación'],
#  ['procesos',
#   'iniciados',
#   'oficio',
#   'petición',
#   'parte',
#   'iniciaren',
#   'corte',
#   'suprema',
#   'declarar',
#   'inaplicabilidad',
#   'precepto',
#   'legal',
#   'ser',
#   'contrario',
#   'constitución',
#   'anterioridad',
#   'aplicación',
#   'reformas',
#   'viii',
#   'seguirán',
#   'siendo',
#   'conocimiento',
#   'resolución',
#   'corte',
#   'completo',
#   'término'],
#  ['decimosexta',
#   'reformas',
#   'introducidas',
#   'viii',
#   'entran',
#   'vigor',
#   'seis',
#   'meses',
#   'después',
#   'publicación',
#   'presente',
#   'reforma',
#   'constitucional',
#   'excepción',
#   'regulado',
#   'disposición',
#   'decimocuarta'],
#  ['decimoseptima',
#   'fuerzas',
#   'orden',
#   'seguridad',
#   'pública',
#   'seguirán',
#   'siendo',
#   'dependientes',
#   'ministerio',
#   'encargado',
#   'defensa',
#   'nacional',
#   'dicte',
#   'nueva',
#   'ley',
#   'cree',
#   'ministerio',
#   'encargado',
#   'seguridad',
#   'pública'],
#  ['decimoctava',
#   'modificaciones',
#   'dispuestas',
#   'nº',
#   'comenzarán',
#   'regir',
#   'después',
#   'próxima',
#   'elección',
#   'general',
#   'parlamentarios'],
#  ['decimonovena',
#   'obstante',
#   'modificación',
#   'n',
#   'constitución',
#   'suspenderá',
#   'derecho',
#   'sufragio',
#   'personas',
#   'procesadas',
#   'hechos',
#   'anteriores',
#   'junio',
#   'delitos',
#   'merezcan',
#   'pena',
#   'aflictiva',
#   'delito',
#   'ley',
#   'califique',
#   'conducta',
#   'terrorista'],
#  ['vigesima',
#   'creen',
#   'tribunales',
#   'especiales',
#   'alude',
#   'párrafo',
#   'cuarto',
#   'número',
#   'reclamaciones',
#   'motivadas',
#   'conducta',
#   'ética',
#   'profesionales',
#   'pertenezcan',
#   'colegios',
#   'profesionales',
#   'conocidas',
#   'tribunales',
#   'ordinarios'],
#  ['vigesima',
#   'primera',
#   'reforma',
#   'introducida',
#   'numeral',
#   '10º',
#   'establece',
#   'obligatoriedad',
#   'segundo',
#   'nivel',
#   'transición',
#   'deber',
#   'financiar',
#   'sistema',
#   'gratuito',
#   'partir',
#   'nivel',
#   'medio',
#   'menor',
#   'destinado',
#   'asegurar',
#   'acceso',
#   'éste',
#   'niveles',
#   'superiores',
#   'entrará',
#   'vigencia',
#   'gradualmente',
#   'forma',
#   'disponga',
#   'ley'],
#  ['vigesimosegunda',
#   'mientras',
#   'entren',
#   'vigencia',
#   'estatutos',
#   'especiales',
#   'refiere',
#   'bis',
#   'territorios',
#   'especiales',
#   'isla',
#   'pascua',
#   'archipiélago',
#   'juan',
#   'fernández',
#   'continuarán',
#   'rigiéndose',
#   'normas',
#   'comunes',
#   'materia',
#   'división',
#   'políticoadministrativa',
#   'gobierno',
#   'administración',
#   'interior'],
#  ['vigésimotercera',
#   'reformas',
#   'introducidas',
#   'artículos',
#   'voluntariedad',
#   'voto',
#   'incorporación',
#   'registro',
#   'electoral',
#   'solo',
#   'ministerio',
#   'ley',
#   'regirán',
#   'momento',
#   'entrar',
#   'vigencia',
#   'respectiva',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'refiere',
#   'inciso',
#   'segundo',
#   'introduce',
#   'mediante',
#   'dichas',
#   'reformas'],
#  ['vigésimocuarta',
#   'chile',
#   'podrá',
#   'reconocer',
#   'jurisdicción',
#   'corte',
#   'penal',
#   'internacional',
#   'términos',
#   'previstos',
#   'tratado',
#   'aprobado',
#   'ciudad',
#   'roma',
#   'julio',
#   'conferencia',
#   'diplomática',
#   'plenipotenciarios',
#   'naciones',
#   'unidas',
#   'establecimiento',
#   'dicha',
#   'corte'],
#  ['efectuar',
#   'reconocimiento',
#   'chile',
#   'reafirma',
#   'facultad',
#   'preferente',
#   'ejercer',
#   'jurisdicción',
#   'penal',
#   'relación',
#   'jurisdicción',
#   'corte',
#   'última',
#   'subsidiaria',
#   'primera',
#   'términos',
#   'previstos',
#   'estatuto',
#   'roma',
#   'creó',
#   'corte',
#   'penal',
#   'internacional'],
#  ['cooperación',
#   'asistencia',
#   'autoridades',
#   'nacionales',
#   'competentes',
#   'corte',
#   'penal',
#   'internacional',
#   'así',
#   'procedimientos',
#   'judiciales',
#   'administrativos',
#   'hubiere',
#   'lugar',
#   'sujetarán',
#   'disponga',
#   'ley',
#   'chilena'],
#  ['jurisdicción',
#   'corte',
#   'penal',
#   'internacional',
#   'términos',
#   'previstos',
#   'estatuto',
#   'sólo',
#   'podrá',
#   'ejercer',
#   'respecto',
#   'crímenes',
#   'competencia',
#   'cuyo',
#   'principio',
#   'ejecución',
#   'posterior',
#   'entrada',
#   'vigor',
#   'chile',
#   'estatuto',
#   'roma'],
#  ['vigésimoquinta',
#   'modificación',
#   'introducida',
#   'inciso',
#   'cuarto',
#   'entrará',
#   'vigencia',
#   'transcurridos',
#   'ciento',
#   'ochenta',
#   'días',
#   'contar',
#   'publicación',
#   'ley',
#   'diario',
#   'oficial'],
#  ['vigesimosexta',
#   'prorrógase',
#   'mandato',
#   'consejeros',
#   'regionales',
#   'ejercicio',
#   'fecha',
#   'publicación',
#   'presente',
#   'reforma',
#   'constitucional',
#   'respectivos',
#   'suplentes',
#   'marzo',
#   'año'],
#  ['primera',
#   'elección',
#   'sufragio',
#   'universal',
#   'votación',
#   'directa',
#   'consejeros',
#   'regionales',
#   'refiere',
#   'inciso',
#   'segundo',
#   'realizará',
#   'conjunto',
#   'elecciones',
#   'presidente',
#   'república',
#   'parlamentarios',
#   'día',
#   'noviembre',
#   'año'],
#  ['efecto',
#   'adecuaciones',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'respectiva',
#   'deberán',
#   'entrar',
#   'vigencia',
#   'julio',
#   'año'],
#  ['vigesimoséptima',
#   'obstante',
#   'dispuesto',
#   'bis',
#   'actuales',
#   'consejeros',
#   'consejo',
#   'directivo',
#   'servicio',
#   'electoral',
#   'cesarán',
#   'cargos',
#   'según',
#   'períodos',
#   'cuales',
#   'nombrados',
#   'nuevos',
#   'consejeros',
#   'corresponda',
#   'designar',
#   'año',
#   'durarán',
#   'cargos',
#   'seis',
#   'ocho',
#   'años',
#   'cada',
#   'conforme',
#   'señale',
#   'presidente',
#   'república',
#   'propuesta',
#   'asimismo',
#   'nuevos',
#   'nombramientos',
#   'corresponda',
#   'efectuar',
#   'año',
#   'durarán',
#   'cargos',
#   'seis',
#   'ocho',
#   'diez',
#   'años',
#   'cada',
#   'conforme',
#   'señale',
#   'presidente',
#   'república',
#   'propuesta',
#   'ambos',
#   'casos',
#   'jefe',
#   'formulará',
#   'proposición',
#   'solo',
#   'acto',
#   'senado',
#   'pronunciará',
#   'conjunto',
#   'propuesta'],
#  ['actualmente',
#   'funciones',
#   'podrán',
#   'ser',
#   'propuestos',
#   'nuevo',
#   'período',
#   'si',
#   'dicha',
#   'prórroga',
#   'superan',
#   'plazo',
#   'total',
#   'diez',
#   'años',
#   'desempeño',
#   'cargo'],
#  ['vigésimo',
#   'octava',
#   'primera',
#   'elección',
#   'sufragio',
#   'universal',
#   'votación',
#   'directa',
#   'gobernadores',
#   'regionales',
#   'verificará',
#   'oportunidad',
#   'señale',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'aluden',
#   'incisos',
#   'cuarto',
#   'quinto',
#   'vez',
#   'promulgada',
#   'ley',
#   'establezca',
#   'nuevo',
#   'procedimiento',
#   'transferencia',
#   'competencias',
#   'refiere'],
#  ['período',
#   'establecido',
#   'inciso',
#   'segundo',
#   'podrá',
#   'ser',
#   'adecuado',
#   'ley',
#   'orgánica',
#   'constitucional',
#   'señalada',
#   'incisos',
#   'cuarto',
#   'quinto',
#   'períodos',
#   'ejercicio',
#   'gobernadores',
#   'regionales',
#   'consejeros',
#   'regionales',
#   'coincidan',
#   'modificación',
#   'requerirá',
#   'aprobación',
#   'voto',
#   'favorable',
#   'tres',
#   'quintas',
#   'partes',
#   'diputados',
#   'senadores',
#   'ejercicio'],
#  ['vez',
#   'asuman',
#   'gobernadores',
#   'regionales',
#   'electos',
#   'presidentes',
#   'consejos',
#   'regionales',
#   'cesarán',
#   'pleno',
#   'derecho',
#   'funciones',
#   'asumidas',
#   'respectivo',
#   'gobernador',
#   'regional'],
#  ['gobernadores',
#   'regionales',
#   'electos',
#   'asuman',
#   'funciones',
#   'atribuciones',
#   'leyes',
#   'otorgan',
#   'expresamente',
#   'intendente',
#   'órgano',
#   'ejecutivo',
#   'gobierno',
#   'regional',
#   'restantes',
#   'funciones',
#   'atribuciones',
#   'leyes',
#   'entregan',
#   'intendente',
#   'entenderán',
#   'referidas',
#   'delegado',
#   'presidencial',
#   'regional',
#   'corresponda',
#   'asimismo',
#   'funciones',
#   'atribuciones',
#   'leyes',
#   'entregan',
#   'gobernador',
#   'entenderán',
#   'atribuidas',
#   'delegado',
#   'presidencial',
#   'provincial'],
#  ['mientras',
#   'asuman',
#   'primeros',
#   'gobernadores',
#   'regionales',
#   'electos',
#   'cargos',
#   'intendentes',
#   'gobernadores',
#   'aplicables',
#   'disposiciones',
#   'constitucionales',
#   'vigentes',
#   'previas',
#   'publicación',
#   'presente',
#   'reforma',
#   'constitucional'],
#  ['anótese',
#   'tómese',
#   'razón',
#   'publíquese',
#   'ricardo',
#   'lagos',
#   'escobar',
#   'presidente',
#   'república',
#   'eduardo',
#   'dockendorff',
#   'vallejos',
#   'ministro',
#   'secretario',
#   'general',
#   'presidenciafrancisco',
#   'vidal',
#   'salinas',
#   'ministro',
#   'interior',
#   'ignacio',
#   'walker',
#   'prieto',
#   'ministro',
#   'relaciones',
#   'exteriores',
#   'jaime',
#   'ravinet',
#   'fuente',
#   'ministro',
#   'defensa',
#   'nacional',
#   'jorge',
#   'rodríguez',
#   'grossi',
#   'ministro',
#   'economía',
#   'fomento',
#   'reconstrucción',
#   'presidente',
#   'comisión',
#   'nacional',
#   'energía',
#   'nicolás',
#   'eyzaguirre',
#   'guzmán',
#   'ministro',
#   'hacienda',
#   'sergio',
#   'bitar',
#   'chacra',
#   'ministro',
#   'educación',
#   'luis',
#   'bates',
#   'hidalgo',
#   'ministro',
#   'justicia',
#   'jaime',
#   'estévez',
#   'valencia',
#   'ministro',
#   'obras',
#   'públicas',
#   'transportes',
#   'telecomunicaciones',
#   'jaime',
#   'campos',
#   'quiroga',
#   'ministro',
#   'agricultura',
#   'yerko',
#   'ljubetic',
#   'godoy',
#   'ministro',
#   'trabajo',
#   'previsión',
#   'social',
#   'pedro',
#   'garcía',
#   'aspillaga',
#   'ministro',
#   'salud',
#   'alfonso',
#   'dulanto',
#   'rencoret',
#   'ministro',
#   'minería',
#   'sonia',
#   'tschorne',
#   'berestescky',
#   'ministra',
#   'vivienda',
#   'urbanismo',
#   'bienes',
#   'nacionales',
#   'osvaldo',
#   'puccio',
#   'huidobro',
#   'ministro',
#   'secretario',
#   'general',
#   'gobierno',
#   'yasna',
#   'provoste',
#   'campillay',
#   'ministra',
#   'planificación'],
#  ['transcribo',
#   'ud',
#   'conocimiento',
#   'saluda',
#   'atentamente',
#   'ud',
#   'rodrigo',
#   'egaña',
#   'baraona',
#   'subsecretario',
#   'general',
#   'presidencia']]

# %% [markdown]
# ## networks

# %%
## original networks
def GoW(text_clean):
    G=nx.Graph()
    for sentence in text_clean:
        if len(sentence)>1:
            pairs=list(zip(sentence,sentence[1:]))
            for pair in pairs:
                if G.has_edge(pair[0],pair[1])==False:
                    G.add_edge(pair[0],pair[1],weight=1)
                else:
                    x=G[pair[0]][pair[1]]['weight']
                    G[pair[0]][pair[1]]['weight']=x+1
        
    return G

# %%
G=GoW(clean(constitucion))

# %%
len(G)
# Out:
# 3205

# %%
nx.is_connected(G)
# Out:
# True

# %%
def plot_graph(G):
    G=nx.maximum_spanning_tree(G,weight='weight')
    eigen_centrality = nx.pagerank(G)
    sorted_centrality = list(zip(*sorted(eigen_centrality.items(), key=operator.itemgetter(1),reverse=True)[:100]))[0]
    pos = nx.spring_layout(G)
    labels=labels={i:i for i in G.nodes if i in sorted_centrality}
    nx.draw_networkx_nodes(G, pos, node_size = 1, node_color='yellow',alpha=0.65) 
    nx.draw_networkx_edges(G, pos, alpha=0.65,width=0.1,edge_color='gray')
    nx.draw_networkx_labels(G,pos,labels,alpha=1,font_size=2.5,font_color='k',font_family='monospace')
    plt.axis('off')
    plt.title('Constitución de Chile')
    plt.savefig('constitucion.pdf', format='pdf', transparent=True, bbox_inches='tight',dpi=800)
    plt.show()

# %%
plot_graph(G)
# Out:
# /home/javier/.local/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
